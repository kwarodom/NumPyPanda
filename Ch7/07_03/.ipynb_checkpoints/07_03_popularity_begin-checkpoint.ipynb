# %% [markdown]
# #Name Popularity
#
# 1. setting and sorting indexes
# 2. selecting rows by index value
# 3. making a stacked line plot in matplotlib

# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
# %matplotlib inline

# %%
import zipfile
zipfile.ZipFile('names.zip').extractall('.')

# %%
import os
os.listdir('names')
# Out:
# ['yob1906.txt',
#  'yob1951.txt',
#  'yob1990.txt',
#  'yob1984.txt',
#  'yob1959.txt',
#  'yob1920.txt',
#  'yob1880.txt',
#  'yob2007.txt',
#  'yob1966.txt',
#  'yob1922.txt',
#  'yob1976.txt',
#  'yob1950.txt',
#  'yob1923.txt',
#  'yob1968.txt',
#  'yob1921.txt',
#  'yob1929.txt',
#  'yob1905.txt',
#  'yob1960.txt',
#  'yob1955.txt',
#  'yob1977.txt',
#  'yob1898.txt',
#  'yob1907.txt',
#  'yob1998.txt',
#  'yob1994.txt',
#  'yob1978.txt',
#  'yob1892.txt',
#  'yob1981.txt',
#  'yob1987.txt',
#  'yob1897.txt',
#  'yob1882.txt',
#  'yob2013.txt',
#  'yob1918.txt',
#  'yob1942.txt',
#  'yob2004.txt',
#  'yob1999.txt',
#  'yob1925.txt',
#  'yob1940.txt',
#  'yob1901.txt',
#  'yob1938.txt',
#  'yob1941.txt',
#  'yob1973.txt',
#  'yob1932.txt',
#  'yob1996.txt',
#  'yob1991.txt',
#  'yob1963.txt',
#  'yob1904.txt',
#  'yob1962.txt',
#  'yob1891.txt',
#  'yob1952.txt',
#  'yob1930.txt',
#  'yob1916.txt',
#  'yob1958.txt',
#  'yob1911.txt',
#  'yob1943.txt',
#  'yob1980.txt',
#  'yob2002.txt',
#  'yob1893.txt',
#  'yob2009.txt',
#  'yob1969.txt',
#  'yob1974.txt',
#  'yob1935.txt',
#  'yob1964.txt',
#  'yob1965.txt',
#  'yob2014.txt',
#  'yob1886.txt',
#  'yob1946.txt',
#  'yob2010.txt',
#  'yob1970.txt',
#  'yob1961.txt',
#  'yob1899.txt',
#  'yob2003.txt',
#  'yob1948.txt',
#  'yob1989.txt',
#  'yob2001.txt',
#  'yob1913.txt',
#  'yob1927.txt',
#  'yob1909.txt',
#  'yob1910.txt',
#  'yob2012.txt',
#  'yob1939.txt',
#  'yob1986.txt',
#  'yob1975.txt',
#  'yob1993.txt',
#  'yob1953.txt',
#  'yob1954.txt',
#  'yob1902.txt',
#  'yob1917.txt',
#  'yob1890.txt',
#  'yob1992.txt',
#  'yob1914.txt',
#  'yob1967.txt',
#  'yob1988.txt',
#  'yob1956.txt',
#  'yob1944.txt',
#  'yob2000.txt',
#  'yob1896.txt',
#  'yob2011.txt',
#  'yob1881.txt',
#  'yob1884.txt',
#  'yob1933.txt',
#  'yob1979.txt',
#  'yob1972.txt',
#  'yob1924.txt',
#  'yob1889.txt',
#  'yob2006.txt',
#  'yob1903.txt',
#  'yob1936.txt',
#  'yob1926.txt',
#  'yob1937.txt',
#  'yob1982.txt',
#  'yob1919.txt',
#  'yob1949.txt',
#  'yob1894.txt',
#  'yob1928.txt',
#  'yob1995.txt',
#  'yob1971.txt',
#  'yob2005.txt',
#  'yob1883.txt',
#  'yob1908.txt',
#  'yob1997.txt',
#  'yob1931.txt',
#  'yob1900.txt',
#  'yob1983.txt',
#  'yob1947.txt',
#  'NationalReadMe.pdf',
#  'yob1915.txt',
#  'yob1895.txt',
#  'yob1985.txt',
#  'yob1912.txt',
#  'yob2008.txt',
#  'yob1934.txt',
#  'yob1945.txt',
#  'yob1885.txt',
#  'yob1888.txt',
#  'yob1887.txt',
#  'yob1957.txt']

# %%
open('names/yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21816\r\n',
#  'Isabella,F,19870\r\n',
#  'Emma,F,18777\r\n',
#  'Olivia,F,17294\r\n',
#  'Ava,F,15480\r\n',
#  'Emily,F,14236\r\n',
#  'Abigail,F,13229\r\n',
#  'Madison,F,12360\r\n',
#  'Mia,F,11512\r\n',
#  'Chloe,F,10970\r\n']

# %%
names2011 = pd.read_csv('names/yob2011.txt')

# %%
names2011.head()
# Out:
#      Sophia  F  21816
# 0  Isabella  F  19870
# 1      Emma  F  18777
# 2    Olivia  F  17294
# 3       Ava  F  15480
# 4     Emily  F  14236
#
# [5 rows x 3 columns]

# %%
names2011 = pd.read_csv('names/yob2011.txt',names=['name','sex','number'])

# %%
names2011.head()
# Out:
#        name sex  number
# 0    Sophia   F   21816
# 1  Isabella   F   19870
# 2      Emma   F   18777
# 3    Olivia   F   17294
# 4       Ava   F   15480
#
# [5 rows x 3 columns]

# %%
names_all = []

for year in range(1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all[-1]['year'] = year

allyears = pd.concat(names_all)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880
#
# [5 rows x 4 columns]

# %%
allyears.tail()
# Out:
#           name sex  number  year
# 33039   Zykeem   M       5  2014
# 33040   Zymeer   M       5  2014
# 33041  Zymiere   M       5  2014
# 33042    Zyran   M       5  2014
# 33043    Zyrin   M       5  2014
#
# [5 rows x 4 columns]

# %% [markdown]
# #start here

# %%
allyears_indexed = allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
#     Aaden     2009       5
#     Aadhira   2012       6
#               2013      10
#               2014      13
#     Aadhya    2007      10
#               2008       9
#               2009      18
#               2010      19
#               2011      52
#               2012     110
#               2013     172
#               2014     249
#     Aadi      2006       5
#               2012       5
#               2013       6
#     Aadison   2009       6
#               2012       5
#     Aaditri   2010       5
#               2012       5
#               2013       6
#               2014      10
#     Aadrika   2013       5
#               2014       5
#     Aadvika   2013       6
#               2014       7
#     Aadya     2003       5
#               2004       8
#               2005      13
#               2006      21
#               2007      16
#               2008      21
#               2009      31
#               2010      33
#               2011      48
#               2012      93
#               2013     105
#               2014     164
#     Aadyn     2008       9
#               2009       7
#     Aafreen   2004       5
#     Aagot     1915       5
#     Aahana    2005      13
#               2006      14
#               2007      25
#               2008      32
#               2009      33
#               2010      64
#               2011      43
#               2012      48
#               2013      46
#               2014      59
#     Aahliyah  2003       6
#               2007       6
#               2008       6
#               2009       6
#                        ...
#
# [1825433 rows x 1 columns]

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8148
# 1883    8012
# 1884    9217
# 1885    9128
# 1886    9890
# 1887    9888
# 1888   11754
# 1889   11648
# 1890   12078
# 1891   11703
# 1892   13173
# 1893   12784
# 1894   13151
# 1895   13446
# 1896   13811
# 1897   13413
# 1898   14406
# 1899   13172
# 1900   16707
# 1901   13136
# 1902   14486
# 1903   14275
# 1904   14962
# 1905   16067
# 1906   16370
# 1907   17580
# 1908   18666
# 1909   19259
# 1910   22848
# 1911   24390
# 1912   32303
# 1913   36641
# 1914   45344
# 1915   58187
# 1916   61437
# 1917   64280
# 1918   67370
# 1919   65840
# 1920   70976
# 1921   73985
# 1922   72171
# 1923   71634
# 1924   73527
# 1925   70601
# 1926   67823
# 1927   70632
# 1928   66866
# 1929   63508
# 1930   64134
# 1931   60293
# 1932   59871
# 1933   55493
# 1934   56918
# 1935   55067
# 1936   54363
# 1937   55640
# 1938   56211
# 1939   54900
#          ...
#
# [135 rows x 1 columns]

# %%
def plotname(sex,name):
    data = allyears_indexed.loc[sex,name]
    
    pp.plot(data.index,data.values)

# %%
pp.figure(figsize=(12,2.5))

names = ['Michael','John','David','Martin','Luis']

for name in names:
    plotname('M',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Emily','Anna','Claire','Elizabeth']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Chiara','Claire','Clare','Clara','Ciara']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
allyears_indexed.loc['F'].loc[names].head()
# Out:
#              number
# name   year
# Chiara 1959       9
#        1960       5
#        1962       8
#        1963       8
#        1964      12
#
# [5 rows x 1 columns]

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).head()
# Out:
#       number
# name  Chiara  Claire  Clare  Clara  Ciara
# year
# 1880     NaN      21     15   1226    NaN
# 1881     NaN      23     20   1242    NaN
# 1882     NaN      30     21   1490    NaN
# 1883     NaN      38     22   1548    NaN
# 1884     NaN      33     38   1852    NaN
#
# [5 rows x 5 columns]

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0).head()
# Out:
#       number
# name  Chiara  Claire  Clare  Clara  Ciara
# year
# 1880       0      21     15   1226      0
# 1881       0      23     20   1242      0
# 1882       0      30     21   1490      0
# 1883       0      38     22   1548      0
# 1884       0      33     38   1852      0
#
# [5 rows x 5 columns]

# %%
variants = allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)
variants.head()
# Out:
#       number
# name  Chiara  Claire  Clare  Clara  Ciara
# year
# 1880       0      21     15   1226      0
# 1881       0      23     20   1242      0
# 1882       0      30     21   1490      0
# 1883       0      38     22   1548      0
# 1884       0      33     38   1852      0
#
# [5 rows x 5 columns]

# %%
pp.figure(figsize=(12,2.5))

pp.stackplot(variants.index,variants.values.T,label=names)
# Out:
# [<matplotlib.collections.PolyCollection at 0x7fef33138890>,
#  <matplotlib.collections.PolyCollection at 0x7fef33138f50>,
#  <matplotlib.collections.PolyCollection at 0x7fef33138d10>,
#  <matplotlib.collections.PolyCollection at 0x7fef330c7a10>,
#  <matplotlib.collections.PolyCollection at 0x7fef330c7f90>]

# %%
pp.figure(figsize=(12,2.5))

palette = seaborn.color_palette()
pp.stackplot(variants.index,variants.values.T,colors=palette)

for i,name in enumerate(names):
    pp.text(1882,5000 + 800*i,name,color=palette[i])
